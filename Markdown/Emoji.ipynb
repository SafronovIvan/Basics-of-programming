# %% [markdown]
# #  Эмодзи в Markdown

# %% [markdown]
# # 📚 Полный список эмодзи для документации и README
#
# ## 🎨 Категории и основные эмодзи
#
# ### 🚀 Прогресс и статус
# | Эмодзи | Код | Значение |
# |--------|-----|----------|
# | ✅ | `:white_check_mark:` | Успех / Готово |
# | ❌ | `:x:` | Ошибка / Неудача |
# | ⚠️ | `:warning:` | Предупреждение |
# | ℹ️ | `:information_source:` | Информация |
# | 🟢 | `:green_circle:` | Активно / Работает |
# | 🔴 | `:red_circle:` | Неактивно / Ошибка |
# | 🟡 | `:yellow_circle:` | В процессе / Ожидание |
# | 🔵 | `:blue_circle:` | Информация |
# | ⚪ | `:white_circle:` | Нейтрально |
# | 🟣 | `:purple_circle:` | Особое внимание |
#
# ### 🛠️ Инструменты и технологии
# | Эмодзи | Код | Значение |
# |--------|-----|----------|
# | 🐍 | `:snake:` | Python |
# | 🐘 | `:elephant:` | PostgreSQL |
# | 🐬 | `:dolphin:` | MySQL |
# | 🐳 | `:whale:` | Docker |
# | 🐧 | `:penguin:` | Linux |
# | 🍎 | `:apple:` | macOS |
# | 🪟 | `:window:` | Windows |
# | 🐚 | `:shell:` | Shell / Terminal |
# | 📦 | `:package:` | Пакет / Библиотека |
# | 🔧 | `:wrench:` | Инструмент / Настройка |
# | ⚙️ | `:gear:` | Настройки / Конфигурация |
# | 🛠️ | `:hammer_and_wrench:` | Инструменты разработки |
# | 🧰 | `:toolbox:` | Набор инструментов |
# | 🧪 | `:test_tube:` | Тестирование |
# | 🐛 | `:bug:` | Баг / Отладка |
# | 🚑 | `:ambulance:` | Срочный фикс |
# | 🔥 | `:fire:` | Удаление кода / Горячо |
# | ✨ | `:sparkles:` | Новая функция |
# | 💡 | `:bulb:` | Идея / Мысль |
# | 🎯 | `:dart:` | Цель / Основное |
# | 📌 | `:pushpin:` | Важно / Закрепить |
#
# ### 🌐 Сеть и интернет
# | Эмодзи | Код | Значение |
# |--------|-----|----------|
# | 🌐 | `:earth_americas:` | Веб / Интернет |
# | 🔗 | `:link:` | Ссылка |
# | 📡 | `:satellite_antenna:` | API / Сеть |
# | ☁️ | `:cloud:` | Облако / Cloud |
# | 🔒 | `:lock:` | Безопасность / SSL |
# | 🔓 | `:unlock:` | Небезопасно |
# | 🌍 | `:earth_africa:` | Глобальный |
#
# ### 💾 Базы данных и файлы
# | Эмодзи | Код | Значение |
# |--------|-----|----------|
# | 🗄️ | `:file_cabinet:` | База данных |
# | 📁 | `:file_folder:` | Папка / Директория |
# | 📂 | `:open_file_folder:` | Открытая папка |
# | 📄 | `:page_facing_up:` | Файл / Документ |
# | 📝 | `:memo:` | Заметки / Документация |
# | 💾 | `:floppy_disk:` | Сохранение |
# | 🗃️ | `:card_file_box:` | Коробка файлов |
#
# ### ⏱️ Время и производительность
# | Эмодзи | Код | Значение |
# |--------|-----|----------|
# | ⏱️ | `:stopwatch:` | Время выполнения |
# | 🚀 | `:rocket:` | Быстро / Производительность |
# | 🐌 | `:snail:` | Медленно |
# | ⚡ | `:zap:` | Быстро / Энергия |
# | 🐢 | `:turtle:` | Медленно |
# | ⏰ | `:alarm_clock:` | Таймер / Дедлайн |
# | ⌛ | `:hourglass_done:` | Ожидание |
#
# ### 👥 Работа с кодом и Git
# | Эмодзи | Код | Значение |
# |--------|-----|----------|
# | 📝 | `:pencil:` | Документация |
# | 🔨 | `:hammer:` | Рефакторинг |
# | 🎨 | `:art:` | Улучшение структуры / UI |
# | 🚚 | `:truck:` | Перемещение файлов |
# | 📈 | `:chart_with_upwards_trend:` | Улучшение производительности |
# | 📉 | `:chart_with_downwards_trend:` | Ухудшение |
# | 🔖 | `:bookmark:` | Тег / Версия |
# | 🏷️ | `:label:` | Метка |
# | 🧹 | `:broom:` | Очистка кода |
# | ♻️ | `:recycle:` | Рефакторинг |
# | 🗑️ | `:wastebasket:` | Удаление |
# | ✏️ | `:pencil2:` | Исправление опечаток |
#
# ### 📚 Документация и обучение
# | Эмодзи | Код | Значение |
# |--------|-----|----------|
# | 📚 | `:books:` | Документация |
# | 📖 | `:book:` | Книга / Руководство |
# | 🎓 | `:mortar_board:` | Обучение |
# | 💡 | `:bulb:` | Пример / Идея |
# | 🔍 | `:mag:` | Поиск / Детали |
# | 📊 | `:bar_chart:` | График / Статистика |
# | 📋 | `:clipboard:` | Чеклист |
# | 📌 | `:pushpin:` | Важное замечание |
# | 💬 | `:speech_balloon:` | Комментарий / Обсуждение |
#
# ### 🎯 Работа с задачами
# | Эмодзи | Код | Значение |
# |--------|-----|----------|
# | ✅ | `:white_check_mark:` | Выполнено |
# | ❌ | `:x:` | Не выполнено |
# | ⏳ | `:hourglass_flowing_sand:` | В процессе |
# | 🔄 | `:arrows_counterclockwise:` | В работе / Обновление |
# | 📌 | `:pushpin:` | Приоритет |
# | 🚧 | `:construction:` | В разработке |
# | 🎯 | `:dart:` | Цель / Мишень |
# | 🏁 | `:checkered_flag:` | Финиш / Готово |
#
# ### 🔔 Коммуникация и уведомления
# | Эмодзи | Код | Значение |
# |--------|-----|----------|
# | 📢 | `:loudspeaker:` | Объявление |
# | 🔔 | `:bell:` | Уведомление |
# | 📧 | `:email:` | Email |
# | 💬 | `:speech_balloon:` | Чат / Сообщение |
# | 📞 | `:telephone:` | Контакт |
# | 📨 | `:incoming_envelope:` | Сообщение |
# | 💌 | `:love_letter:` | Письмо |
#
# ### 🎨 Оформление и структура
# | Эмодзи | Код | Значение |
# |--------|-----|----------|
# | 📌 | `:pushpin:` | Заголовок |
# | 🔹 | `:small_blue_diamond:` | Маркер списка |
# | 🔸 | `:small_orange_diamond:` | Маркер списка |
# | ▪️ | `:black_small_square:` | Маркер |
# | ▫️ | `:white_small_square:` | Маркер |
# | ➖ | `:heavy_minus_sign:` | Разделитель |
# | ✨ | `:sparkles:` | Украшение |
# | ⭐ | `:star:` | Избранное |
# | 💎 | `:gem:` | Важное |
